# %% [markdown]
# <a href="https://colab.research.google.com/github/RaziehSh1987/ML-Learning-Code-and-Documents/blob/main/R_Squared_Confusion_metrix_and_accuracy_rate_and_error_rate_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **R Squared:**

# %% [markdown]
# ![photo_2023-06-24_21-29-48.jpg](data:image/jpeg;base64,...)![photo_2023-06-24_21-29-45.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Confusion metrix and accuracy rate and error rate:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

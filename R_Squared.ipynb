# %% [markdown]
# <a href="https://colab.research.google.com/github/RaziehSh1987/ML-Learning-Code-and-Documents/blob/main/R_Squared.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **R Squared:**

# %% [markdown]
# ![photo_2023-06-24_21-29-48.jpg](data:image/jpeg;base64,...)![photo_2023-06-24_21-29-45.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <a href="https://colab.research.google.com/github/RaziehSh1987/ML-Learning-Code-and-Documents/blob/main/decision_tree_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# we have CART =>means Classification and Regression Decision Tree.
# but in this file we investugate  Desion tree regression

# %% [markdown]
# # Decision Tree Regression
#
#
# ```
# Decidion tree doesn't need "feature scaling" because it split the dataset and make an average
# ```

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)![2.jpg](data:image/jpeg;base64,...)![4.jpg](data:image/jpeg;base64,...)![3.jpg](data:image/jpeg;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ML_Udemy_tutorial/Teacher_Files/part2-Regression/Section 8 _ Decision Tree Regression/Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Decision Tree Regression model on the whole dataset

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)#random_state=>we will have a same result each time
regressor.fit(X,y) #train the desion tree regression on the X and y
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
regressor.predict([[5.8]])
# Out:
# array([150000.])

# %% [markdown]
# ## Visualising the Decision Tree Regression results (higher resolution)
#
#
# ```
# with Decision Tree => we have same predict in a range of datas ,forexample here the predicted for 5.8 and 6 and 6.2 and 6.3 are same so predicted value for all of them is 15000
# ```

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
